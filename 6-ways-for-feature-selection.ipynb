# %% [markdown]
# - <a href='#1'>Prepare</a>
# - <a href='#2'>Feature Selection</a>
#     - <a href='#2-1'>1. Filter</a>
#         - <a href='#2-1-1'>1.1 Pearson Correlation</a>
#         - <a href='#2-1-2'>1.2 Chi-2</a>
#     - <a href='#2-2'>2. Wrapper</a>
#     - <a href='#2-3'>3. Embeded</a>
#         - <a href='#2-3-1'>3.1 Logistics Regression L1</a>
#         - <a href='#2-3-2'>3.2 Random Forest</a>
#         - <a href='#2-3-3'>3.3 LightGBM</a>
# - <a href='#3'>Summary</a>

# %% [markdown]
# # <a id='1'>Prepare</a>

# %%
import pandas as pd
import numpy as np
import gc
import warnings
warnings.filterwarnings("ignore")
application_train = pd.read_csv('./application_train.csv')

# %% [markdown]
# ### Stratified Sampling (ratio = 0.1)

# %%
application_sample1 = application_train.loc[application_train.TARGET==1].sample(frac=0.1, replace=False)
print('label 1 sample size:', str(application_sample1.shape[0]))
application_sample0 = application_train.loc[application_train.TARGET==0].sample(frac=0.1, replace=False)
print('label 0 sample size:', str(application_sample0.shape[0]))
application = pd.concat([application_sample1, application_sample0], axis=0).sort_values('SK_ID_CURR')
# Out:
# label 1 sample size: 2482
# label 0 sample size: 28269

# %% [markdown]
# ### Impute missing values

# %%
categorical_list = []
numerical_list = []
for i in application.columns.tolist():
    if application[i].dtype=='object':
        categorical_list.append(i)
    else:
        numerical_list.append(i)
print('Number of categorical features:', str(len(categorical_list)))
print('Number of numerical features:', str(len(numerical_list)))
# Out:
# Number of categorical features: 16
# Number of numerical features: 106

# %%
from sklearn.preprocessing import Imputer
application[numerical_list] = Imputer(strategy='median').fit_transform(application[numerical_list])
# Out:
# /Users/anqib/anaconda3/lib/python3.7/site-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)

# %% [markdown]
# ### Deal with Categorical features: OneHotEncoding

# %%
del application_train; gc.collect()
application = pd.get_dummies(application, drop_first=True)
print(application.shape)
# Out:
# (30751, 227)

# %% [markdown]
# ### Feature matrix and target

# %%
X = application.drop(['SK_ID_CURR', 'TARGET'], axis=1)
y = application.TARGET
feature_name = X.columns.tolist()

# %% [markdown]
# # <a id='2'>Feature Selection</a>
# - select **100** features from 226
# - **xxx_support**: list to represent select this feature or not
# - **xxx_feature**: the name of selected features

# %% [markdown]
# ## <a id='2-1'>1 Filter</a>
# - documentation for **SelectKBest**: http://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.SelectKBest.html
#
# ###  <a id='2-1-1'>1.1 Pearson Correlation</a>
# **Note**
# - Normalization: no
# - Impute missing values: yes

# %%
def cor_selector(X, y):
    cor_list = []
    # calculate the correlation with y for each feature
    for i in X.columns.tolist():
        cor = np.corrcoef(X[i], y)[0, 1]
        cor_list.append(cor)
    # replace NaN with 0
    cor_list = [0 if np.isnan(i) else i for i in cor_list]
    # feature name
    cor_feature = X.iloc[:,np.argsort(np.abs(cor_list))[-100:]].columns.tolist()
    # feature selection? 0 for not select, 1 for select
    cor_support = [True if i in cor_feature else False for i in feature_name]
    return cor_support, cor_feature

# %%
cor_support, cor_feature = cor_selector(X, y)
print(str(len(cor_feature)), 'selected features')
# Out:
# 100 selected features

# %% [markdown]
# ###  <a id='2-1-2'>1.2 Chi-2</a>
#
# **Note**
# - Normalization: MinMaxScaler (values should be bigger than 0)
# - Impute missing values: yes

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.preprocessing import MinMaxScaler
X_norm = MinMaxScaler().fit_transform(X)
chi_selector = SelectKBest(chi2, k=100)
chi_selector.fit(X_norm, y)
# Out:
# SelectKBest(k=100, score_func=<function chi2 at 0x121e3dd08>)

# %%
chi_support = chi_selector.get_support()
chi_feature = X.loc[:,chi_support].columns.tolist()
print(str(len(chi_feature)), 'selected features')
# Out:
# 100 selected features

# %% [markdown]
# ## <a id='2-2'>2. Wrapper</a>
# - documentation for **RFE**: http://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.RFE.html
#
# **Note**
# - Normalization: depend on the used model; yes for LR
# - Impute missing values: depend on the used model; yes for LR

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
rfe_selector = RFE(estimator=LogisticRegression(), n_features_to_select=100, step=10, verbose=5)
rfe_selector.fit(X_norm, y)
# Out:
# Fitting estimator with 225 features.
# Fitting estimator with 215 features.
# Fitting estimator with 205 features.
# Fitting estimator with 195 features.
# Fitting estimator with 185 features.
# Fitting estimator with 175 features.
# Fitting estimator with 165 features.
# Fitting estimator with 155 features.
# Fitting estimator with 145 features.
# Fitting estimator with 135 features.
# Fitting estimator with 125 features.
# Fitting estimator with 115 features.
# Fitting estimator with 105 features.
# RFE(estimator=LogisticRegression(C=1.0, class_weight=None, dual=False,
#                                  fit_intercept=True, intercept_scaling=1,
#                                  l1_ratio=None, max_iter=100,
#                                  multi_class='warn', n_jobs=None, penalty='l2',
#                                  random_state=None, solver='warn', tol=0.0001,
#                                  verbose=0, warm_start=False),
#     n_features_to_select=100, step=10, verbose=5)

# %%
rfe_support = rfe_selector.get_support()
rfe_feature = X.loc[:,rfe_support].columns.tolist()
print(str(len(rfe_feature)), 'selected features')
# Out:
# 100 selected features

# %% [markdown]
# ## <a id='2-3'>3. Embeded</a>
# - documentation for **SelectFromModel**: http://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.SelectFromModel.html
# ###  <a id='2-3-1'>3.1 Logistics Regression L1</a>
# **Note**
# - Normalization: Yes
# - Impute missing values: Yes

# %%
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import LogisticRegression

embeded_lr_selector = SelectFromModel(LogisticRegression(penalty="l1"), '1.25*median')
embeded_lr_selector.fit(X_norm, y)
# Out:
# SelectFromModel(estimator=LogisticRegression(C=1.0, class_weight=None,
#                                              dual=False, fit_intercept=True,
#                                              intercept_scaling=1, l1_ratio=None,
#                                              max_iter=100, multi_class='warn',
#                                              n_jobs=None, penalty='l1',
#                                              random_state=None, solver='warn',
#                                              tol=0.0001, verbose=0,
#                                              warm_start=False),
#                 max_features=None, norm_order=1, prefit=False,
#                 threshold='1.25*median')

# %%
embeded_lr_support = embeded_lr_selector.get_support()
embeded_lr_feature = X.loc[:,embeded_lr_support].columns.tolist()
print(str(len(embeded_lr_feature)), 'selected features')
# Out:
# 106 selected features

# %% [markdown]
# ###  <a id='2-3-2'>3.2 Random Forest</a>
# **Note**
# - Normalization: No
# - Impute missing values: Yes

# %%
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import RandomForestClassifier

embeded_rf_selector = SelectFromModel(RandomForestClassifier(n_estimators=100), threshold='1.25*median')
embeded_rf_selector.fit(X, y)
# Out:
# SelectFromModel(estimator=RandomForestClassifier(bootstrap=True,
#                                                  class_weight=None,
#                                                  criterion='gini',
#                                                  max_depth=None,
#                                                  max_features='auto',
#                                                  max_leaf_nodes=None,
#                                                  min_impurity_decrease=0.0,
#                                                  min_impurity_split=None,
#                                                  min_samples_leaf=1,
#                                                  min_samples_split=2,
#                                                  min_weight_fraction_leaf=0.0,
#                                                  n_estimators=100, n_jobs=None,
#                                                  oob_score=False,
#                                                  random_state=None, verbose=0,
#                                                  warm_start=False),
#                 max_features=None, norm_order=1, prefit=False,
#                 threshold='1.25*median')

# %%
embeded_rf_support = embeded_rf_selector.get_support()
embeded_rf_feature = X.loc[:,embeded_rf_support].columns.tolist()
print(str(len(embeded_rf_feature)), 'selected features')
# Out:
# 95 selected features

# %% [markdown]
# ###  <a id='2-3-3'>3.3 LightGBM</a>
# **Note**
# - Normalization: No
# - Impute missing values: No

# %%
from sklearn.feature_selection import SelectFromModel
from lightgbm import LGBMClassifier

lgbc=LGBMClassifier(n_estimators=500, learning_rate=0.05, num_leaves=32, colsample_bytree=0.2,
            reg_alpha=3, reg_lambda=1, min_split_gain=0.01, min_child_weight=40)

embeded_lgb_selector = SelectFromModel(lgbc, threshold='1.25*median')
embeded_lgb_selector.fit(X, y)
# Out:
# SelectFromModel(estimator=LGBMClassifier(boosting_type='gbdt',
#                                          class_weight=None,
#                                          colsample_bytree=0.2,
#                                          importance_type='split',
#                                          learning_rate=0.05, max_depth=-1,
#                                          min_child_samples=20,
#                                          min_child_weight=40,
#                                          min_split_gain=0.01, n_estimators=500,
#                                          n_jobs=-1, num_leaves=32,
#                                          objective=None, random_state=None,
#                                          reg_alpha=3, reg_lambda=1, silent=True,
#                                          subsample=1.0,
#                                          subsample_for_bin=200000,
#                                          subsample_freq=0),
#                 max_features=None, norm_order=1, prefit=False,
#                 threshold='1.25*median')

# %%
embeded_lgb_support = embeded_lgb_selector.get_support()
embeded_lgb_feature = X.loc[:,embeded_lgb_support].columns.tolist()
print(str(len(embeded_lgb_feature)), 'selected features')
# Out:
# 110 selected features

# %% [markdown]
# # <a id='3'>Summary</a>

# %%
pd.set_option('display.max_rows', None)
# put all selection together
feature_selection_df = pd.DataFrame({'Feature':feature_name, 'Pearson':cor_support, 'Chi-2':chi_support, 'RFE':rfe_support, 'Logistics':embeded_lr_support,
                                    'Random Forest':embeded_rf_support, 'LightGBM':embeded_lgb_support})
# count the selected times for each feature
feature_selection_df['Total'] = np.sum(feature_selection_df, axis=1)
# display the top 100
feature_selection_df = feature_selection_df.sort_values(['Total','Feature'] , ascending=False)
feature_selection_df.index = range(1, len(feature_selection_df)+1)
feature_selection_df.head(100)
# Out:
#                                                Feature  Pearson  Chi-2    RFE  \
# 1                               REG_CITY_NOT_LIVE_CITY     True   True   True
# 2                              OCCUPATION_TYPE_Drivers     True   True   True
# 3                           NAME_FAMILY_STATUS_Married     True   True   True
# 4    NAME_EDUCATION_TYPE_Secondary / secondary special     True   True   True
# 5                                       FLAG_OWN_CAR_Y     True   True   True
# 6                                      FLAG_DOCUMENT_3     True   True   True
# 7                                         EXT_SOURCE_3     True   True   True
# 8                                         EXT_SOURCE_2     True   True   True
# 9                                         EXT_SOURCE_1     True   True   True
# 10                            DEF_30_CNT_SOCIAL_CIRCLE     True   True   True
# 11                                   DAYS_REGISTRATION     True   True   True
# 12                              DAYS_LAST_PHONE_CHANGE     True   True   True
# 13                                     DAYS_ID_PUBLISH     True   True   True
# 14                                       CODE_GENDER_M     True   True   True
# 15                                        CNT_CHILDREN     True   True   True
# 16                                     AMT_GOODS_PRICE     True   True   True
# 17                                    YEARS_BUILD_MODE     True  False   True
# 18                                    YEARS_BUILD_MEDI     True  False   True
# 19                        YEARS_BEGINEXPLUATATION_MEDI     True  False   True
# 20                         YEARS_BEGINEXPLUATATION_AVG     True  False   True
# 21                              REG_CITY_NOT_WORK_CITY     True   True  False
# 22                                REGION_RATING_CLIENT     True   True  False
# 23                          REGION_POPULATION_RELATIVE     True   True  False
# 24                                         OWN_CAR_AGE     True  False   True
# 25                               ORGANIZATION_TYPE_XNA     True   True   True
# 26            ORGANIZATION_TYPE_Business Entity Type 3     True   True  False
# 27                            OCCUPATION_TYPE_Laborers     True   True  False
# 28                          OCCUPATION_TYPE_Core staff     True   True   True
# 29                            NAME_INCOME_TYPE_Working     True   True   True
# 30                 NAME_HOUSING_TYPE_House / apartment     True   True  False
# 31             NAME_FAMILY_STATUS_Single / not married     True   True  False
# 32                                      LIVINGAREA_AVG     True  False   True
# 33                                       FLOORSMAX_AVG     True   True   True
# 34                                     FLAG_WORK_PHONE     True   True  False
# 35                                          FLAG_PHONE     True   True  False
# 36                                     FLAG_DOCUMENT_6     True   True   True
# 37                                      ELEVATORS_MEDI     True   True   True
# 38                                       DAYS_EMPLOYED     True   True   True
# 39                                          DAYS_BIRTH     True   True  False
# 40                                      APARTMENTS_AVG     True  False   True
# 41                                    AMT_INCOME_TOTAL     True  False   True
# 42                                          AMT_CREDIT     True  False   True
# 43                                     YEARS_BUILD_AVG     True  False  False
# 44                       WALLSMATERIAL_MODE_Monolithic     True   True   True
# 45                                      TOTALAREA_MODE     True  False   True
# 46                          REG_REGION_NOT_WORK_REGION     True   True   True
# 47                         REGION_RATING_CLIENT_W_CITY     True   True  False
# 48                 ORGANIZATION_TYPE_Transport: type 4     True   True  False
# 49                 ORGANIZATION_TYPE_Transport: type 3     True   True   True
# 50                     ORGANIZATION_TYPE_Trade: type 3     True   True   True
# 51                     ORGANIZATION_TYPE_Self-employed     True   True  False
# 52                        ORGANIZATION_TYPE_Restaurant     True   True   True
# 53                  ORGANIZATION_TYPE_Industry: type 9     True   True   True
# 54                       ORGANIZATION_TYPE_Agriculture     True   True   True
# 55                OCCUPATION_TYPE_Waiters/barmen staff     True   True   True
# 56                            OBS_60_CNT_SOCIAL_CIRCLE     True  False  False
# 57                                  NONLIVINGAREA_MODE     True   True  False
# 58                    NAME_INCOME_TYPE_Maternity leave     True   True   True
# 59               NAME_INCOME_TYPE_Commercial associate    False   True   True
# 60                  NAME_HOUSING_TYPE_Rented apartment     True   True  False
# 61                NAME_EDUCATION_TYPE_Higher education     True   True  False
# 62                  NAME_CONTRACT_TYPE_Revolving loans     True   True  False
# 63                                     LIVINGAREA_MODE     True  False   True
# 64                                     LIVINGAREA_MEDI     True  False   True
# 65                               LIVINGAPARTMENTS_MEDI     True  False   True
# 66                             LIVE_CITY_NOT_WORK_CITY     True   True  False
# 67                             HOUR_APPR_PROCESS_START     True  False  False
# 68                                      FLOORSMIN_MODE     True  False   True
# 69                                       FLOORSMIN_AVG     True  False   True
# 70                                      FLOORSMAX_MODE     True   True  False
# 71                                      FLOORSMAX_MEDI     True   True  False
# 72                                      FLAG_EMP_PHONE     True   True   True
# 73                                     FLAG_DOCUMENT_7     True   True   True
# 74                                    FLAG_DOCUMENT_13     True   True   True
# 75                             EMERGENCYSTATE_MODE_Yes     True   True   True
# 76                                       ELEVATORS_AVG     True   True   True
# 77                            DEF_60_CNT_SOCIAL_CIRCLE     True   True  False
# 78                          AMT_REQ_CREDIT_BUREAU_YEAR    False  False   True
# 79                          AMT_REQ_CREDIT_BUREAU_WEEK    False  False   True
# 80                                         AMT_ANNUITY    False  False   True
# 81                  WEEKDAY_APPR_PROCESS_START_TUESDAY    False   True  False
# 82                 WEEKDAY_APPR_PROCESS_START_THURSDAY    False  False  False
# 83                   WEEKDAY_APPR_PROCESS_START_SUNDAY    False  False  False
# 84                 WEEKDAY_APPR_PROCESS_START_SATURDAY    False  False  False
# 85                           WALLSMATERIAL_MODE_Wooden     True   True  False
# 86                            WALLSMATERIAL_MODE_Panel     True   True  False
# 87                            ORGANIZATION_TYPE_Police    False   True   True
# 88                            ORGANIZATION_TYPE_Mobile    False   True   True
# 89                          ORGANIZATION_TYPE_Military    False   True   True
# 90                  ORGANIZATION_TYPE_Industry: type 7    False   True   True
# 91                  ORGANIZATION_TYPE_Industry: type 5    False   True   True
# 92                  ORGANIZATION_TYPE_Industry: type 2    False   True   True
# 93                 ORGANIZATION_TYPE_Industry: type 13     True   True   True
# 94                 ORGANIZATION_TYPE_Industry: type 12    False   True   True
# 95            ORGANIZATION_TYPE_Business Entity Type 2    False   True  False
# 96                         OCCUPATION_TYPE_Sales staff     True   True  False
# 97                  OCCUPATION_TYPE_Low-skill Laborers     True   True  False
# 98                            OCCUPATION_TYPE_HR staff    False   True   True
# 99                       OCCUPATION_TYPE_Cooking staff     True   True  False
# 100                           OBS_30_CNT_SOCIAL_CIRCLE     True  False  False
#
#      Logistics  Random Forest  LightGBM  Total
# 1         True           True      True      6
# 2         True           True      True      6
# 3         True           True      True      6
# 4         True           True      True      6
# 5         True           True      True      6
# 6         True           True      True      6
# 7         True           True      True      6
# 8         True           True      True      6
# 9         True           True      True      6
# 10        True           True      True      6
# 11        True           True      True      6
# 12        True           True      True      6
# 13        True           True      True      6
# 14        True           True      True      6
# 15        True           True      True      6
# 16        True           True      True      6
# 17        True           True      True      5
# 18        True           True      True      5
# 19        True           True      True      5
# 20        True           True      True      5
# 21        True           True      True      5
# 22        True           True      True      5
# 23        True           True      True      5
# 24        True           True      True      5
# 25        True          False      True      5
# 26        True           True      True      5
# 27        True           True      True      5
# 28        True          False      True      5
# 29       False           True      True      5
# 30        True           True      True      5
# 31        True           True      True      5
# 32        True           True      True      5
# 33       False           True      True      5
# 34        True           True      True      5
# 35        True           True      True      5
# 36        True          False      True      5
# 37        True          False      True      5
# 38       False           True      True      5
# 39        True           True      True      5
# 40        True           True      True      5
# 41        True           True      True      5
# 42        True           True      True      5
# 43        True           True      True      4
# 44        True          False     False      4
# 45       False           True      True      4
# 46        True          False     False      4
# 47       False           True      True      4
# 48        True          False      True      4
# 49        True          False     False      4
# 50        True          False     False      4
# 51        True           True     False      4
# 52        True          False     False      4
# 53        True          False     False      4
# 54        True          False     False      4
# 55        True          False     False      4
# 56        True           True      True      4
# 57       False           True      True      4
# 58        True          False     False      4
# 59       False           True      True      4
# 60        True          False      True      4
# 61       False           True      True      4
# 62        True          False      True      4
# 63       False           True      True      4
# 64       False           True      True      4
# 65       False           True      True      4
# 66        True           True     False      4
# 67        True           True      True      4
# 68       False           True      True      4
# 69       False           True      True      4
# 70       False           True      True      4
# 71       False           True      True      4
# 72       False          False      True      4
# 73        True          False     False      4
# 74        True          False     False      4
# 75        True          False     False      4
# 76       False          False      True      4
# 77       False           True      True      4
# 78        True           True      True      4
# 79        True           True      True      4
# 80        True           True      True      4
# 81       False           True      True      3
# 82        True           True      True      3
# 83        True           True      True      3
# 84        True           True      True      3
# 85        True          False     False      3
# 86       False          False      True      3
# 87        True          False     False      3
# 88        True          False     False      3
# 89        True          False     False      3
# 90        True          False     False      3
# 91        True          False     False      3
# 92        True          False     False      3
# 93       False          False     False      3
# 94        True          False     False      3
# 95        True          False      True      3
# 96       False           True     False      3
# 97        True          False     False      3
# 98        True          False     False      3
# 99        True          False     False      3
# 100      False           True      True      3
